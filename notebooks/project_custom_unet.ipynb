# %%
# !pip install rasterio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rasterio in /user/swetasah/.local/lib/python3.9/site-packages (1.4.3)
# Requirement already satisfied: click>=4.0 in /cvmfs/soft.ccr.buffalo.edu/versions/2023.01/easybuild/software/avx512/Compiler/gcccore/11.2.0/python/3.9.6/lib/python3.9/site-packages (from rasterio) (8.0.1)
# Requirement already satisfied: certifi in /cvmfs/soft.ccr.buffalo.edu/versions/2023.01/easybuild/software/avx512/Compiler/gcccore/11.2.0/python/3.9.6/lib/python3.9/site-packages (from rasterio) (2021.5.30)
# Requirement already satisfied: importlib-metadata in /cvmfs/soft.ccr.buffalo.edu/versions/2023.01/easybuild/software/avx512/Compiler/gcccore/11.2.0/python/3.9.6/lib/python3.9/site-packages (from rasterio) (4.6.3)
# Requirement already satisfied: attrs in /cvmfs/soft.ccr.buffalo.edu/versions/2023.01/easybuild/software/avx512/Compiler/gcccore/11.2.0/python/3.9.6/lib/python3.9/site-packages (from rasterio) (21.2.0)
# Requirement already satisfied: cligj>=0.5 in /user/swetasah/.local/lib/python3.9/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click-plugins in /user/swetasah/.local/lib/python3.9/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /cvmfs/soft.ccr.buffalo.edu/versions/2023.01/easybuild/software/avx512/Compiler/gcccore/11.2.0/python/3.9.6/lib/python3.9/site-packages (from rasterio) (2.4.7)
# Requirement already satisfied: affine in /user/swetasah/.local/lib/python3.9/site-packages (from rasterio) (2.4.0)
# Collecting numpy>=1.24
#   Using cached numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
# Requirement already satisfied: zipp>=0.5 in /cvmfs/soft.ccr.buffalo.edu/versions/2023.01/easybuild/software/avx512/Compiler/gcccore/11.2.0/python/3.9.6/lib/python3.9/site-packages (from importlib-metadata->rasterio) (3.5.0)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 2.0.2 which is incompatible.
# tensorflow 2.11.0 requires gast<=0.4.0,>=0.2.1, but you have gast 0.5.2 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2
# WARNING: You are using pip version 21.2.2; however, version 25.0.1 is available.
# You should consider upgrading via the '/cvmfs/soft.ccr.buffalo.edu/versions/2023.01/easybuild/software/avx512/Compiler/gcccore/11.2.0/python/3.9.6/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import zipfile

zip_input_path = "/projects/academic/courses/cse676s25/swetasah/DL Project/WildfireSpreadTS.zip"
extract_path = "/projects/academic/courses/cse676s25/swetasah/DL Project/dataset"
with zipfile.ZipFile(zip_input_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import os
import glob
from collections import defaultdict

dataset_path = "/projects/academic/courses/cse676s25/swetasah/DL Project/dataset/WildfireSpreadTS"
years = defaultdict(list)

for i in ['2018', '2019', '2020', '2021']:
    year_path = os.path.join(dataset_path, i)

    tiff_files = glob.glob(os.path.join(year_path, '**', '*.tif'), recursive=True)
    tiff_files += glob.glob(os.path.join(year_path, '**', '*.tiff'), recursive=True)
    years[i].extend(tiff_files)

for i in sorted(years.keys()):
    print(f"{i}: {len(years[i])} TIFF files")
# Out:
# 2018: 3773 TIFF files
# 2019: 1425 TIFF files
# 2020: 4292 TIFF files
# 2021: 4117 TIFF files

# %%
import pandas as pd
import os

info = []

for yr, paths in years.items():
    for path in paths:
        fire_id = os.path.basename(os.path.dirname(path))  
        date_path = os.path.splitext(os.path.basename(path))[0]  
        
        info.append({
            'yr': yr,
            'fire_id': fire_id,
            'date': date_path,
            'path': path
        })

df = pd.DataFrame(info)
df['date'] = pd.to_datetime(df['date'], errors='coerce')  

df_2018 = df[df['yr'] == '2018'].reset_index(drop=True)
df_2019 = df[df['yr'] == '2019'].reset_index(drop=True)
df_2020 = df[df['yr'] == '2020'].reset_index(drop=True)
df_2021 = df[df['yr'] == '2021'].reset_index(drop=True)

print("df of 2018 shape :", df_2018.shape)
print("df of 2019 shape:", df_2019.shape)
print("df of 2020 shape:", df_2020.shape)
print("df of 2021 shape:", df_2021.shape)
# Out:
# df of 2018 shape : (3773, 4)
# df of 2019 shape: (1425, 4)
# df of 2020 shape: (4292, 4)
# df of 2021 shape: (4117, 4)

# %%
id = df_2018['fire_id'].value_counts()
print(id)
# Out:
# fire_21889697    94
# fire_21889719    67
# fire_21889754    56
# fire_21997775    52
# fire_21890524    52
#                  ..
# fire_21458801    11
# fire_21890063    11
# fire_21615469    11
# fire_22343689    11
# fire_21997854    10
# Name: fire_id, Length: 176, dtype: int64

# %%
import rasterio
from collections import Counter

def get_shape_band(df_year, year_label):
    print(f"\nFor {year_label}:")
    shapes = []
    bands = []
    
    for path in df_year['path']:
        try:
            with rasterio.open(path) as src:
                shape = (src.height, src.width)
                b_count = src.count
                shapes.append(shape)
                bands.append(b_count)
        except Exception as e:
            print(f"{path} not found: {e}")
            continue

    shape_num = Counter(shapes)
    band_num = Counter(bands)

    print(f"\nImage shapes in {year_label}:")
    for s, c in shape_num.items():
        print(f"Shape {s}: {c} images")

    print(f"\nBand counts in {year_label}:")
    for b, c in band_num.items():
        print(f" {b} Bands: {c} images")

get_shape_band(df_2018, "2018")
get_shape_band(df_2019, "2019")
get_shape_band(df_2020, "2020")
get_shape_band(df_2021, "2021")
# Out:
# For 2018:
#
# Image shapes in 2018:
# Shape (304, 247): 14 images
# Shape (326, 274): 11 images
# Shape (304, 248): 19 images
# Shape (307, 254): 35 images
# Shape (327, 280): 15 images
# Shape (327, 270): 14 images
# Shape (324, 270): 31 images
# Shape (323, 269): 20 images
# Shape (340, 295): 15 images
# Shape (309, 252): 16 images
# Shape (356, 308): 15 images
# Shape (354, 307): 11 images
# Shape (352, 299): 12 images
# Shape (329, 283): 19 images
# Shape (333, 291): 33 images
# Shape (299, 222): 74 images
# Shape (352, 302): 17 images
# Shape (349, 298): 16 images
# Shape (338, 292): 25 images
# Shape (329, 248): 22 images
# Shape (298, 224): 108 images
# Shape (306, 243): 23 images
# Shape (325, 278): 12 images
# Shape (336, 294): 41 images
# Shape (338, 297): 14 images
# Shape (339, 288): 50 images
# Shape (347, 301): 18 images
# Shape (351, 311): 14 images
# Shape (300, 231): 13 images
# Shape (298, 233): 73 images
# Shape (299, 236): 20 images
# Shape (307, 249): 16 images
# Shape (322, 268): 16 images
# Shape (303, 246): 12 images
# Shape (305, 215): 12 images
# Shape (304, 219): 15 images
# Shape (303, 218): 19 images
# Shape (326, 260): 14 images
# Shape (344, 286): 24 images
# Shape (338, 280): 19 images
# Shape (329, 271): 29 images
# Shape (345, 291): 23 images
# Shape (327, 271): 15 images
# Shape (324, 268): 13 images
# Shape (348, 298): 21 images
# Shape (349, 304): 15 images
# Shape (298, 221): 78 images
# Shape (300, 223): 94 images
# Shape (298, 223): 16 images
# Shape (298, 228): 41 images
# Shape (303, 234): 18 images
# Shape (306, 241): 18 images
# Shape (297, 234): 24 images
# Shape (305, 247): 43 images
# Shape (306, 249): 24 images
# Shape (315, 259): 22 images
# Shape (313, 266): 20 images
# Shape (303, 211): 46 images
# Shape (304, 212): 14 images
# Shape (304, 215): 16 images
# Shape (306, 217): 17 images
# Shape (307, 223): 16 images
# Shape (303, 216): 15 images
# Shape (303, 217): 17 images
# Shape (302, 217): 20 images
# Shape (306, 223): 16 images
# Shape (314, 235): 37 images
# Shape (320, 244): 38 images
# Shape (318, 240): 28 images
# Shape (315, 236): 28 images
# Shape (313, 235): 17 images
# Shape (326, 254): 21 images
# Shape (315, 240): 18 images
# Shape (321, 249): 25 images
# Shape (319, 248): 14 images
# Shape (317, 247): 13 images
# Shape (317, 248): 18 images
# Shape (314, 244): 14 images
# Shape (314, 245): 11 images
# Shape (315, 246): 14 images
# Shape (321, 254): 20 images
# Shape (313, 244): 20 images
# Shape (312, 244): 12 images
# Shape (318, 253): 12 images
# Shape (335, 274): 17 images
# Shape (317, 251): 12 images
# Shape (311, 244): 21 images
# Shape (318, 254): 12 images
# Shape (320, 255): 16 images
# Shape (324, 261): 31 images
# Shape (337, 280): 18 images
# Shape (342, 286): 57 images
# Shape (330, 270): 22 images
# Shape (336, 280): 17 images
# Shape (341, 286): 34 images
# Shape (333, 276): 29 images
# Shape (336, 283): 35 images
# Shape (336, 286): 28 images
# Shape (341, 296): 18 images
# Shape (315, 224): 26 images
# Shape (304, 208): 52 images
# Shape (338, 271): 13 images
# Shape (302, 231): 23 images
# Shape (299, 228): 52 images
# Shape (305, 245): 32 images
# Shape (306, 248): 23 images
# Shape (327, 276): 18 images
# Shape (304, 250): 10 images
# Shape (311, 265): 18 images
# Shape (307, 215): 17 images
# Shape (307, 222): 14 images
# Shape (304, 220): 27 images
# Shape (305, 221): 13 images
# Shape (322, 246): 21 images
# Shape (304, 222): 19 images
# Shape (302, 218): 16 images
# Shape (318, 242): 15 images
# Shape (300, 217): 20 images
# Shape (318, 246): 25 images
# Shape (317, 246): 12 images
# Shape (303, 228): 24 images
# Shape (329, 265): 20 images
# Shape (325, 260): 15 images
# Shape (315, 247): 28 images
# Shape (325, 259): 14 images
# Shape (313, 247): 15 images
# Shape (315, 250): 13 images
# Shape (319, 256): 30 images
# Shape (329, 270): 33 images
# Shape (310, 215): 29 images
# Shape (304, 207): 33 images
# Shape (320, 233): 35 images
# Shape (310, 216): 29 images
# Shape (315, 225): 29 images
# Shape (310, 220): 16 images
# Shape (326, 252): 20 images
# Shape (327, 252): 26 images
# Shape (346, 286): 27 images
# Shape (306, 246): 16 images
# Shape (306, 218): 16 images
# Shape (306, 220): 16 images
# Shape (315, 232): 38 images
# Shape (305, 219): 15 images
# Shape (306, 221): 17 images
# Shape (318, 241): 19 images
# Shape (325, 252): 16 images
# Shape (331, 264): 23 images
# Shape (330, 264): 17 images
# Shape (322, 255): 12 images
# Shape (316, 249): 16 images
# Shape (342, 284): 16 images
# Shape (335, 275): 17 images
# Shape (336, 278): 15 images
# Shape (317, 252): 25 images
# Shape (328, 268): 28 images
# Shape (347, 307): 18 images
# Shape (299, 224): 20 images
# Shape (300, 230): 12 images
# Shape (300, 238): 16 images
# Shape (331, 270): 14 images
# Shape (342, 285): 19 images
# Shape (301, 234): 21 images
# Shape (300, 233): 14 images
# Shape (307, 259): 19 images
# Shape (306, 259): 11 images
#
# Band counts in 2018:
#  23 Bands: 3773 images
#
# For 2019:
#
# Image shapes in 2019:
# Shape (308, 233): 19 images
# Shape (302, 248): 19 images
# Shape (328, 282): 34 images
# Shape (326, 282): 13 images
# Shape (328, 285): 32 images
# Shape (305, 216): 20 images
# Shape (347, 306): 27 images
# Shape (298, 221): 18 images
# Shape (302, 229): 27 images
# Shape (320, 269): 11 images
# Shape (324, 279): 13 images
# Shape (330, 288): 23 images
# Shape (331, 289): 18 images
# Shape (332, 291): 18 images
# Shape (303, 213): 14 images
# Shape (306, 217): 16 images
# Shape (305, 218): 15 images
# Shape (318, 242): 32 images
# Shape (324, 253): 17 images
# Shape (316, 247): 15 images
# Shape (335, 258): 15 images
# Shape (319, 235): 20 images
# Shape (326, 246): 15 images
# Shape (325, 275): 24 images
# Shape (326, 278): 20 images
# Shape (326, 279): 41 images
# Shape (323, 277): 33 images
# Shape (326, 283): 17 images
# Shape (319, 242): 22 images
# Shape (316, 236): 20 images
# Shape (311, 231): 30 images
# Shape (309, 230): 23 images
# Shape (317, 246): 16 images
# Shape (317, 248): 12 images
# Shape (320, 254): 15 images
# Shape (324, 257): 15 images
# Shape (324, 258): 16 images
# Shape (323, 258): 14 images
# Shape (319, 255): 15 images
# Shape (317, 253): 16 images
# Shape (327, 266): 14 images
# Shape (309, 217): 25 images
# Shape (336, 258): 19 images
# Shape (341, 280): 20 images
# Shape (298, 230): 14 images
# Shape (303, 237): 25 images
# Shape (301, 235): 26 images
# Shape (304, 242): 28 images
# Shape (309, 253): 28 images
# Shape (325, 282): 19 images
# Shape (311, 266): 14 images
# Shape (314, 231): 48 images
# Shape (314, 230): 18 images
# Shape (306, 232): 19 images
# Shape (314, 242): 21 images
# Shape (325, 268): 18 images
# Shape (344, 292): 24 images
# Shape (323, 268): 15 images
# Shape (327, 246): 12 images
# Shape (332, 262): 21 images
# Shape (298, 234): 19 images
# Shape (304, 246): 15 images
# Shape (308, 260): 39 images
# Shape (307, 259): 15 images
# Shape (307, 221): 14 images
# Shape (299, 219): 21 images
# Shape (329, 261): 19 images
# Shape (328, 264): 36 images
# Shape (300, 217): 19 images
#
# Band counts in 2019:
#  23 Bands: 1425 images
#
# For 2020:
#
# Image shapes in 2020:
# Shape (336, 293): 28 images
# Shape (300, 233): 39 images
# Shape (308, 234): 15 images
# Shape (346, 290): 45 images
# Shape (349, 305): 21 images
# Shape (321, 269): 11 images
# Shape (302, 249): 19 images
# Shape (326, 281): 28 images
# Shape (327, 285): 18 images
# Shape (306, 219): 23 images
# Shape (323, 257): 15 images
# Shape (325, 262): 15 images
# Shape (353, 305): 17 images
# Shape (305, 241): 14 images
# Shape (325, 274): 50 images
# Shape (316, 264): 17 images
# Shape (301, 246): 16 images
# Shape (327, 284): 41 images
# Shape (330, 288): 34 images
# Shape (334, 292): 59 images
# Shape (310, 265): 18 images
# Shape (311, 266): 20 images
# Shape (325, 267): 12 images
# Shape (326, 267): 20 images
# Shape (323, 266): 15 images
# Shape (320, 263): 14 images
# Shape (338, 287): 16 images
# Shape (353, 306): 12 images
# Shape (334, 286): 17 images
# Shape (351, 307): 15 images
# Shape (339, 299): 24 images
# Shape (342, 277): 22 images
# Shape (301, 228): 21 images
# Shape (303, 233): 20 images
# Shape (303, 234): 15 images
# Shape (304, 239): 19 images
# Shape (306, 244): 12 images
# Shape (319, 264): 15 images
# Shape (318, 264): 13 images
# Shape (319, 265): 31 images
# Shape (322, 268): 12 images
# Shape (301, 243): 14 images
# Shape (303, 248): 18 images
# Shape (311, 259): 14 images
# Shape (307, 256): 12 images
# Shape (326, 280): 15 images
# Shape (313, 265): 21 images
# Shape (327, 283): 15 images
# Shape (331, 288): 24 images
# Shape (331, 289): 26 images
# Shape (306, 213): 49 images
# Shape (306, 217): 21 images
# Shape (324, 252): 13 images
# Shape (320, 256): 18 images
# Shape (316, 252): 18 images
# Shape (321, 265): 16 images
# Shape (326, 274): 17 images
# Shape (308, 215): 16 images
# Shape (320, 235): 18 images
# Shape (343, 276): 16 images
# Shape (299, 226): 35 images
# Shape (305, 235): 32 images
# Shape (298, 226): 20 images
# Shape (298, 227): 59 images
# Shape (306, 237): 15 images
# Shape (302, 235): 29 images
# Shape (297, 230): 76 images
# Shape (301, 236): 75 images
# Shape (305, 239): 17 images
# Shape (298, 236): 29 images
# Shape (297, 235): 20 images
# Shape (305, 245): 27 images
# Shape (307, 248): 36 images
# Shape (304, 245): 15 images
# Shape (300, 242): 32 images
# Shape (298, 240): 25 images
# Shape (301, 244): 19 images
# Shape (300, 245): 63 images
# Shape (308, 255): 61 images
# Shape (310, 258): 13 images
# Shape (321, 271): 14 images
# Shape (308, 257): 17 images
# Shape (316, 266): 14 images
# Shape (320, 273): 18 images
# Shape (322, 276): 19 images
# Shape (308, 259): 22 images
# Shape (310, 262): 16 images
# Shape (325, 279): 17 images
# Shape (328, 285): 17 images
# Shape (330, 287): 38 images
# Shape (329, 286): 32 images
# Shape (308, 218): 38 images
# Shape (303, 213): 22 images
# Shape (305, 215): 16 images
# Shape (304, 215): 14 images
# Shape (317, 239): 67 images
# Shape (301, 217): 54 images
# Shape (323, 247): 33 images
# Shape (299, 215): 71 images
# Shape (301, 218): 21 images
# Shape (303, 223): 18 images
# Shape (311, 233): 27 images
# Shape (319, 246): 16 images
# Shape (318, 248): 14 images
# Shape (324, 257): 14 images
# Shape (334, 274): 18 images
# Shape (331, 270): 45 images
# Shape (344, 288): 65 images
# Shape (345, 288): 92 images
# Shape (344, 289): 30 images
# Shape (341, 286): 29 images
# Shape (337, 281): 39 images
# Shape (306, 210): 16 images
# Shape (322, 237): 26 images
# Shape (339, 266): 9 images
# Shape (336, 262): 19 images
# Shape (342, 272): 15 images
# Shape (339, 269): 19 images
# Shape (341, 272): 18 images
# Shape (341, 274): 16 images
# Shape (351, 294): 13 images
# Shape (298, 222): 25 images
# Shape (298, 224): 33 images
# Shape (297, 224): 24 images
# Shape (298, 228): 15 images
# Shape (298, 235): 20 images
# Shape (306, 247): 30 images
# Shape (306, 249): 66 images
# Shape (309, 262): 33 images
# Shape (312, 266): 30 images
# Shape (326, 282): 14 images
# Shape (306, 212): 15 images
# Shape (306, 214): 10 images
# Shape (311, 225): 17 images
# Shape (309, 222): 14 images
# Shape (315, 232): 17 images
# Shape (299, 211): 13 images
# Shape (318, 238): 29 images
# Shape (307, 224): 13 images
# Shape (299, 213): 35 images
# Shape (314, 234): 31 images
# Shape (299, 216): 35 images
# Shape (317, 245): 18 images
# Shape (297, 219): 36 images
# Shape (299, 220): 27 images
# Shape (303, 228): 29 images
# Shape (300, 224): 14 images
# Shape (320, 252): 25 images
# Shape (343, 285): 33 images
# Shape (341, 285): 42 images
# Shape (327, 267): 29 images
# Shape (310, 217): 19 images
# Shape (309, 217): 27 images
# Shape (339, 265): 12 images
# Shape (312, 224): 13 images
# Shape (331, 253): 12 images
# Shape (338, 268): 14 images
# Shape (329, 253): 14 images
# Shape (341, 282): 18 images
# Shape (305, 240): 11 images
# Shape (307, 249): 26 images
# Shape (324, 279): 19 images
# Shape (310, 263): 16 images
# Shape (310, 264): 34 images
# Shape (323, 249): 16 images
# Shape (346, 289): 16 images
# Shape (346, 291): 11 images
# Shape (346, 301): 15 images
# Shape (300, 235): 31 images
# Shape (306, 245): 23 images
# Shape (311, 252): 19 images
# Shape (306, 250): 23 images
# Shape (309, 231): 15 images
# Shape (308, 231): 14 images
# Shape (324, 270): 13 images
# Shape (324, 271): 24 images
#
# Band counts in 2020:
#  23 Bands: 4292 images
#
# For 2021:
# Image shapes in 2021:
# Shape (304, 245): 27 images
# Shape (305, 245): 29 images
# Shape (303, 247): 13 images
# Shape (344, 296): 15 images
# Shape (315, 231): 22 images
# Shape (315, 232): 53 images
# Shape (303, 222): 28 images
# Shape (301, 226): 27 images
# Shape (345, 305): 17 images
# Shape (344, 270): 19 images
# Shape (347, 278): 14 images
# Shape (348, 278): 14 images
# Shape (350, 281): 23 images
# Shape (314, 259): 40 images
# Shape (325, 280): 37 images
# Shape (338, 297): 17 images
# Shape (337, 295): 47 images
# Shape (300, 226): 18 images
# Shape (299, 226): 18 images
# Shape (299, 228): 19 images
# Shape (321, 267): 17 images
# Shape (300, 245): 15 images
# Shape (326, 278): 45 images
# Shape (330, 285): 17 images
# Shape (327, 281): 29 images
# Shape (333, 292): 29 images
# Shape (329, 286): 28 images
# Shape (309, 222): 30 images
# Shape (313, 230): 18 images
# Shape (303, 217): 12 images
# Shape (302, 217): 18 images
# Shape (302, 218): 11 images
# Shape (335, 275): 22 images
# Shape (342, 285): 43 images
# Shape (341, 284): 21 images
# Shape (329, 270): 24 images
# Shape (336, 278): 27 images
# Shape (330, 271): 20 images
# Shape (342, 287): 23 images
# Shape (334, 281): 26 images
# Shape (328, 251): 12 images
# Shape (336, 265): 19 images
# Shape (334, 262): 18 images
# Shape (329, 259): 29 images
# Shape (330, 261): 24 images
# Shape (330, 260): 20 images
# Shape (297, 227): 63 images
# Shape (297, 226): 63 images
# Shape (297, 228): 62 images
# Shape (297, 230): 41 images
# Shape (302, 235): 72 images
# Shape (304, 238): 23 images
# Shape (305, 243): 32 images
# Shape (305, 247): 15 images
# Shape (321, 270): 13 images
# Shape (304, 212): 17 images
# Shape (305, 213): 16 images
# Shape (304, 215): 11 images
# Shape (312, 228): 36 images
# Shape (313, 231): 36 images
# Shape (312, 226): 60 images
# Shape (311, 228): 28 images
# Shape (318, 237): 20 images
# Shape (317, 238): 40 images
# Shape (319, 242): 27 images
# Shape (301, 219): 13 images
# Shape (299, 217): 35 images
# Shape (298, 219): 31 images
# Shape (302, 226): 41 images
# Shape (342, 284): 14 images
# Shape (319, 230): 25 images
# Shape (305, 209): 49 images
# Shape (315, 225): 66 images
# Shape (304, 208): 38 images
# Shape (309, 216): 75 images
# Shape (308, 215): 19 images
# Shape (317, 230): 59 images
# Shape (316, 228): 48 images
# Shape (337, 261): 18 images
# Shape (331, 253): 18 images
# Shape (316, 231): 30 images
# Shape (326, 247): 26 images
# Shape (328, 250): 67 images
# Shape (337, 264): 19 images
# Shape (320, 238): 41 images
# Shape (338, 265): 12 images
# Shape (331, 254): 48 images
# Shape (338, 267): 14 images
# Shape (324, 245): 27 images
# Shape (340, 269): 21 images
# Shape (323, 245): 30 images
# Shape (322, 243): 40 images
# Shape (340, 271): 33 images
# Shape (327, 254): 25 images
# Shape (348, 290): 17 images
# Shape (298, 220): 22 images
# Shape (300, 227): 35 images
# Shape (298, 225): 91 images
# Shape (304, 237): 21 images
# Shape (304, 242): 38 images
# Shape (309, 254): 28 images
# Shape (307, 256): 26 images
# Shape (304, 210): 41 images
# Shape (302, 212): 55 images
# Shape (314, 230): 22 images
# Shape (315, 234): 18 images
# Shape (316, 236): 28 images
# Shape (318, 240): 23 images
# Shape (300, 215): 31 images
# Shape (318, 241): 47 images
# Shape (317, 242): 52 images
# Shape (309, 232): 27 images
# Shape (298, 218): 26 images
# Shape (297, 219): 46 images
# Shape (298, 221): 33 images
# Shape (304, 230): 26 images
# Shape (308, 212): 30 images
# Shape (309, 215): 17 images
# Shape (306, 209): 15 images
# Shape (306, 210): 23 images
# Shape (307, 214): 21 images
# Shape (334, 255): 26 images
# Shape (311, 220): 20 images
# Shape (322, 245): 22 images
# Shape (335, 264): 12 images
# Shape (340, 270): 14 images
# Shape (321, 243): 26 images
# Shape (332, 259): 13 images
# Shape (338, 268): 29 images
# Shape (351, 295): 15 images
# Shape (300, 228): 18 images
# Shape (298, 229): 18 images
# Shape (307, 252): 42 images
# Shape (308, 254): 27 images
# Shape (308, 255): 41 images
# Shape (302, 210): 22 images
# Shape (318, 239): 22 images
# Shape (303, 229): 23 images
# Shape (325, 247): 20 images
# Shape (321, 244): 27 images
# Shape (350, 292): 14 images
# Shape (304, 254): 17 images
# Shape (328, 268): 23 images
# Shape (332, 255): 16 images
#
# Band counts in 2021:
#  23 Bands: 4117 images

# %%
import rasterio
import matplotlib.pyplot as plot
import numpy as np

def normalize(band):
    return (band - band.min()) / (band.max() - band.min() + 1e-5)

def img_plot(path):
    with rasterio.open(path) as src:
        img = src.read()
        img = np.nan_to_num(img, nan=0.0)
        
        red = normalize(img[3]) 
        gre = normalize(img[2]) 
        blue = normalize(img[1])  
        rgb = np.stack([red, gre, blue], axis=-1)

        plot.figure(figsize=(15,5))
        plot.imshow(rgb)
        plot.show()

path = df_2018.iloc[0]['path']
img_plot(path)

# %%
# !pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 2.1 MB/s eta 0:00:011
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1
# WARNING: You are using pip version 21.2.2; however, version 25.0.1 is available.
# You should consider upgrading via the '/cvmfs/soft.ccr.buffalo.edu/versions/2023.01/easybuild/software/avx512/Compiler/gcccore/11.2.0/python/3.9.6/bin/python3.9 -m pip install --upgrade pip' command.

# %% [markdown]
# **Data cleaning and preprocessing**

# %%
import os
import zipfile
import rasterio
import numpy as np
from tqdm import tqdm

def resize(img, target_shape=(351, 303)):
    bands, h, w = img.shape
    th, tw = target_shape

    top_crop = max((h - th) // 2, 0)
    left_crop = max((w - tw) // 2, 0)
    img = img[:, top_crop:top_crop+th, left_crop:left_crop+tw]

    pad_h = max(th - img.shape[1], 0)
    pad_w = max(tw - img.shape[2], 0)
    pad_top = pad_h // 2
    pad_bottom = pad_h - pad_top
    pad_left = pad_w // 2
    pad_right = pad_w - pad_left

    return np.pad(img, ((0, 0), (pad_top, pad_bottom), (pad_left, pad_right)), mode='constant')

# %%
import os
import numpy as np
import rasterio
from tqdm import tqdm

# Data cleaning and preprocessing
def clean_and_preprocess(df_year,
                         year_label,
                         target_shape=(351, 303),
                         output_dir="/projects/academic/courses/cse676s25/swetasah/DL Project/preprocessed_images"):
    output_path = os.path.join(output_dir, year_label)
    os.makedirs(output_path, exist_ok=True)

    valid_count, skipped_count = 0, 0

    for _, row in tqdm(df_year.iterrows(),
                       total=len(df_year),
                       desc=f"Processing {year_label}"):
        fire_id = row['fire_id']
        date_str = row['date'].strftime('%Y-%m-%d')
        tiff_path = row['path']

        try:
            with rasterio.open(tiff_path) as src:
                if src.count != 23:
                    skipped_count += 1
                    continue

                img = src.read()
                nan_ratio = np.isnan(img).sum() / img.size

                if nan_ratio > 0.5:
                    skipped_count += 1
                    continue

                img = np.nan_to_num(img, nan=0.0)
                img = np.clip(img, a_min=0, a_max=None)

                if np.all(img == 0):
                    skipped_count += 1
                    continue

                aligned = resize(img, target_shape)

                fire_folder = os.path.join(output_path, fire_id)
                os.makedirs(fire_folder, exist_ok=True)
                save_path = os.path.join(fire_folder, f"{date_str}.npy")
                np.save(save_path, aligned)
                valid_count += 1

        except Exception as e:
            skipped_count += 1
            continue

    print(f"{year_label} done — saved: {valid_count}, skipped: {skipped_count}")

# %%
clean_and_preprocess(df_2018, "2018")
clean_and_preprocess(df_2019, "2019")
clean_and_preprocess(df_2020, "2020")
clean_and_preprocess(df_2021, "2021")
# Out:
# Processing 2018: 100%|██████████| 3773/3773 [08:59<00:00,  6.99it/s]
# 2018 done — saved: 3773, skipped: 0
# Processing 2019: 100%|██████████| 1425/1425 [03:46<00:00,  6.30it/s]
# 2019 done — saved: 1425, skipped: 0
# Processing 2020: 100%|██████████| 4292/4292 [11:16<00:00,  6.34it/s]
# 2020 done — saved: 4292, skipped: 0
# Processing 2021: 100%|██████████| 4117/4117 [09:55<00:00,  6.91it/s]
# 2021 done — saved: 4117, skipped: 0

# %% [markdown]
# **Stats of processed data**

# %%
import os
import numpy as np

def processed_stats(path):
    img = np.load(path)
    
    stats = {
        "shape": img.shape,
        "min": float(np.min(img)),
        "max": float(np.max(img)),
        "mean": float(np.mean(img)),
        "std": float(np.std(img)),
        "zero_ratio": float(np.sum(img == 0) / img.size)
    }
    return stats

main = "/projects/academic/courses/cse676s25/swetasah/DL Project/preprocessed_images/2018"
fires = os.listdir(main)[:3]  

for i in fires:
    fire_path = os.path.join(main, i)
    fire_files = sorted(os.listdir(fire_path))[:2] 
    
    for f in fire_files:
        path = os.path.join(fire_path, f)
        print(f"\n{i} | {f}")
        
        stats = processed_stats(path)
        for k, v in stats.items():
            print(f" {k}: {v}")
# Out:
# fire_21458798 | 2018-01-01.npy
#  shape: (23, 351, 303)
#  min: 0.0
#  max: 9577.0
#  mean: 398.49102783203125
#  std: 931.8948364257812
#  zero_ratio: 0.4026602957583012
#
# fire_21458798 | 2018-01-02.npy
#  shape: (23, 351, 303)
#  min: 0.0
#  max: 9577.0
#  mean: 708.2575073242188
#  std: 1717.3690185546875
#  zero_ratio: 0.39053700985111517
#
# fire_21458801 | 2018-01-25.npy
#  shape: (23, 351, 303)
#  min: 0.0
#  max: 8789.0
#  mean: 448.0985107421875
#  std: 857.6573486328125
#  zero_ratio: 0.31708310184418664
#
# fire_21458801 | 2018-01-26.npy
#  shape: (23, 351, 303)
#  min: 0.0
#  max: 8739.0
#  mean: 517.0399780273438
#  std: 988.6417846679688
#  zero_ratio: 0.30672465239835023
#
# fire_21458806 | 2018-01-12.npy
#  shape: (23, 351, 303)
#  min: 0.0
#  max: 9988.0
#  mean: 575.6929321289062
#  std: 1430.4210205078125
#  zero_ratio: 0.41671521295570657
#
# fire_21458806 | 2018-01-13.npy
#  shape: (23, 351, 303)
#  min: 0.0
#  max: 9988.0
#  mean: 711.9537353515625
#  std: 1799.932373046875
#  zero_ratio: 0.3956115789951347

# %% [markdown]
# **Visualizing the processed images**

# %%
import random
import os
import numpy as np
import matplotlib.pyplot as plot

def normalize(band):
    return (band - band.min()) / (band.max() - band.min() + 1e-5)

def plot_yrs(path):
    img = np.load(path)
    
    red = normalize(img[3])  
    gre = normalize(img[2])  
    blue = normalize(img[1]) 
    rgb = np.stack([red, gre, blue], axis=-1)
    
    plot.figure(figsize=(10, 5))
    plot.imshow(rgb)
    plot.title(f"{os.path.basename(path)}")
    plot.show()

def years_files(year):
   
    year_files = f"/projects/academic/courses/cse676s25/swetasah/DL Project/preprocessed_images/{year}"
    
    if not os.path.exists(year_files):
        print(f"no folder {year} at {year_files}")
        return

    folders = os.listdir(year_files)
    
    if not folders:
        print(f"No fire data in {year}")
        return

    random_fire = random.choice(folders)
    
    print(f"\n{year}, random fire choosen: {random_fire}")

    fire_path = os.path.join(year_files, random_fire)
    
    imgs = sorted([f for f in os.listdir(fire_path) if f.endswith('.npy')])
    if not imgs:
        print(f"No files found in {fire_path}")
        return

    for i in imgs[:3]:
        plot_yrs(os.path.join(fire_path, i))

for year in ["2018","2019", "2020", "2021"]:
    years_files(year)
# Out:
# 2018, random fire choosen: fire_21890065
# 2019, random fire choosen: fire_23410607
# 2020, random fire choosen: fire_24191933
# 2021, random fire choosen: fire_25205936

# %% [markdown]
# **Checking images per year**

# %%
import matplotlib.pyplot as plot

def plotting_gr(df_year, year_label):
    
    numbers = df_year['fire_id'].value_counts()
    plot.figure(figsize=(12, 4))
    numbers.hist(bins=20)
    
    plot.title(f"Images of fire for yr {year_label}")
    plot.xlabel("Images")
    plot.ylabel("Fires")
    plot.grid(True)
    plot.show()
    
plotting_gr(df_2018, "2018")
plotting_gr(df_2019, "2019")
plotting_gr(df_2020, "2020")
plotting_gr(df_2021, "2021")

# %% [markdown]
# **Combining all df**

# %%
import pandas as pd

df_all = pd.concat([df_2018, df_2019, df_2020, df_2021], ignore_index=True)

print(f" total fire files: {df_all['fire_id'].nunique()} | total images: {len(df_all)}")
# Out:
#  total fire files: 607 | total images: 13607

# %% [markdown]
# **Splitting data to train, val and test set**

# %%
from sklearn.model_selection import train_test_split

def data_split(df, test_size=0.15, val_size=0.15, seed=42):
    
    fire_uni = df['fire_id'].unique()
    
    train_ids, temp_ids = train_test_split(fire_uni, test_size=test_size + val_size, random_state=seed)
    val_ids, test_ids = train_test_split(temp_ids, test_size=test_size / (test_size + val_size), random_state=seed)
    
    return train_ids, val_ids, test_ids

train_ids, val_ids, test_ids = data_split(df_all)
print(f"Train set: {len(train_ids)}")
print(f"Val set: {len(val_ids)}") 
print (f"Test set: {len(test_ids)}")
# Out:
# Train set: 424
# Val set: 91
# Test set: 92

# %% [markdown]
# **Normalizing train set**

# %%
import numpy as np
import os
from tqdm import tqdm

def min_max(base_folder, fire_uni):
    mins = np.full(23, np.inf)
    maxs = np.full(23, -np.inf)

    for year in ['2018', '2019', '2020', '2021']:
        for fire_id in fire_uni:
            fire_path = os.path.join(base_folder, year, fire_id)
            if not os.path.isdir(fire_path):
                continue
            for file in os.listdir(fire_path):
                if file.endswith('.npy'):
                    img = np.load(os.path.join(fire_path, file))
                    band_min = img.reshape(23, -1).min(axis=1)
                    band_max = img.reshape(23, -1).max(axis=1)
                    mins = np.minimum(mins, band_min)
                    maxs = np.maximum(maxs, band_max)

    return mins, maxs

base_folder = "/projects/academic/courses/cse676s25/swetasah/DL Project/preprocessed_images"
min_vals, max_vals = min_max(base_folder, train_ids)

np.save("min_vals_global.npy", min_vals)
np.save("max_vals_global.npy", max_vals)

# %% [markdown]
# **Exploratory data analysis**

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import random

min_vals = np.load("./min_vals_global.npy")
max_vals = np.load("./max_vals_global.npy")

def normalize(img, min_vals, max_vals):
    norm = (img - min_vals[:, None, None]) / (max_vals[:, None, None] - min_vals[:, None, None] + 1e-6)
    
    return np.clip(norm, 0, 1)

def plotting_imgs(img_path):
    img = np.load(img_path)
    img_norm = normalize(img, min_vals, max_vals)

    rgb = np.stack([img_norm[3], img_norm[2],  img_norm[1]], axis=-1)

    plt.figure(figsize=(10, 5))
    plt.imshow(rgb)
    plt.title(f"{os.path.basename(img_path)}")
    plt.show()

random_path = "/projects/academic/courses/cse676s25/swetasah/DL Project/preprocessed_images/2018/fire_21458798/2018-01-01.npy"
plotting_imgs(random_path)

# %% [markdown]
# **Modelling**
#
# **Model: ConvNet-based encoder-decoder using U-Net**

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from glob import glob
from torch.utils.data import DataLoader

class fire_dataset(Dataset):
    def __init__(self, main, fire_uni, transform=None):
        self.samples = []
        self.transform = transform

        for yr in ['2018', '2019', '2020', '2021']:
            for id in fire_uni:
                fire_path = os.path.join(main, yr, id)
                if not os.path.isdir(fire_path):
                    continue

                file = sorted(glob(os.path.join(fire_path, '*.npy')))
                for i in range(len(file) - 1):
                    self.samples.append((file[i], file[i+1]))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        input_path, target_path = self.samples[idx]
        input_img = np.load(input_path).astype(np.float32)
        target_img = np.load(target_path).astype(np.float32)

        input_img /= 1e4
        target_img /= 1e4

        input_tensor = torch.from_numpy(input_img)
        target_tensor = torch.from_numpy(target_img)

        if self.transform:
            input_tensor = self.transform(input_tensor)
            target_tensor = self.transform(target_tensor)

        return input_tensor, target_tensor

train_dataset = fire_dataset("/projects/academic/courses/cse676s25/swetasah/DL Project/preprocessed_images", train_ids)
val_dataset = fire_dataset("/projects/academic/courses/cse676s25/swetasah/DL Project/preprocessed_images", val_ids)
test_dataset = fire_dataset("/projects/academic/courses/cse676s25/swetasah/DL Project/preprocessed_images", test_ids)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=8, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=8, num_workers=2, pin_memory=True)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class UNet_model(nn.Module):
    def __init__(self, in_channels=23, out_channels=23):
        super(UNet_model, self).__init__()

        self.enc1 = self.conv_block(in_channels, 64)
        self.enc2 = self.conv_block(64, 128)
        self.enc3 = self.conv_block(128, 256)
        
        self.pool = nn.MaxPool2d(2)
        
        self.bottleneck = self.conv_block(256, 512)
        
        self.up3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.dec3 = self.conv_block(512, 256)  
        
        self.up2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec2 = self.conv_block(256, 128)  
        
        self.up1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec1 = self.conv_block(128, 64)   
        
        self.final = nn.Conv2d(64, out_channels, kernel_size=1)
    
    def conv_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
    
    def forward(self, x):

        e1 = self.enc1(x)             
        e2 = self.enc2(self.pool(e1))    
        e3 = self.enc3(self.pool(e2))    
        
        b = self.bottleneck(self.pool(e3)) 
        
        d3 = self.up3(b)                    

        e3_cropped = F.adaptive_avg_pool2d(e3, d3.shape[2:])
        d3 = self.dec3(torch.cat([d3, e3_cropped], dim=1))
        
        d2 = self.up2(d3)                  
        e2_cropped = F.adaptive_avg_pool2d(e2, d2.shape[2:])
        d2 = self.dec2(torch.cat([d2, e2_cropped], dim=1))
        
        d1 = self.up1(d2)                  
        e1_cropped = F.adaptive_avg_pool2d(e1, d1.shape[2:])
        d1 = self.dec1(torch.cat([d1, e1_cropped], dim=1))
        
        out = self.final(d1)

        out = F.interpolate(out, size=(x.shape[2], x.shape[3]), mode='bilinear', align_corners=False)
        return out

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = UNet_model(in_channels=23, out_channels=23).to(device)
print(model)
# Out:
# UNet_model(
#   (enc1): Sequential(
#     (0): Conv2d(23, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (enc2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (enc3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bottleneck): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (up3): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (dec3): Sequential(
#     (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (up2): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (dec2): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (up1): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (dec1): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (final): Conv2d(64, 23, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# **Training a subset of data to verify results**

# %%
import random
import torch
import torch.optim as optim
import torch.nn as nn
from tqdm.notebook import tqdm 
from torch.utils.data import Subset, DataLoader

ratio = 0.1

train_sub_size = int(len(train_dataset) * ratio)
tr_ind = random.sample(range(len(train_dataset)), train_sub_size)
train_sub_ds = Subset(train_dataset, tr_ind)
train_sub_dl = DataLoader(train_sub_ds, batch_size=8, shuffle=True, num_workers=4, pin_memory=True)

val_sub_size = int(len(val_dataset) * ratio)
val_ind = random.sample(range(len(val_dataset)), val_sub_size)
val_sub_ds = Subset(val_dataset, val_ind)
val_sub_dl = DataLoader(val_sub_ds, batch_size=8, shuffle=False, num_workers=4, pin_memory=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

model = UNet_model(in_channels=23, out_channels=23).to(device)
loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)
num_epoch = 10

for epoch in range(num_epoch):
    model.train()
    train_loss = 0.0
    for inputs, targets in tqdm(train_sub_dl, desc=f"Epoch {epoch+1}/{num_epoch} [Train]", leave=False):
        inputs = inputs.to(device)
        targets = targets.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    tr_loss_total = train_loss / len(train_sub_dl)

    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for inputs, targets in tqdm(val_sub_dl, desc=f"Epoch {epoch+1}/{num_epoch} [Val]", leave=False):
            inputs = inputs.to(device)
            targets = targets.to(device)
            outputs = model(inputs)
            loss = loss(outputs, targets)
            val_loss += loss.item()

    val_loss_total = val_loss / len(val_sub_dl)
    
    print(f"\nEpoch {epoch+1}/{num_epoch}")
    print(f"Train Loss: {tr_loss_total:.4f} ")
    print(f"Val Loss: {val_loss_total:.4f}")
# Out:
# cuda
# Epoch 1/10 [Train]:   0%|          | 0/112 [00:00<?, ?it/s]
# Epoch 1/10 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
# Epoch 1/10
# Train Loss: 0.0088
# Val Loss: 0.0045
# Epoch 2/10 [Train]:   0%|          | 0/112 [00:00<?, ?it/s]
# Epoch 2/10 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
# Epoch 2/10
# Train Loss: 0.0039
# Val Loss: 0.0037
# Epoch 3/10 [Train]:   0%|          | 0/112 [00:00<?, ?it/s]
# Epoch 3/10 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
# Epoch 3/10
# Train Loss: 0.0034
# Val Loss: 0.0033
# Epoch 4/10 [Train]:   0%|          | 0/112 [00:00<?, ?it/s]
# Epoch 4/10 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
# Epoch 4/10
# Train Loss: 0.0033
# Val Loss: 0.0033
# Epoch 5/10 [Train]:   0%|          | 0/112 [00:00<?, ?it/s]
# Epoch 5/10 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
# Epoch 5/10
# Train Loss: 0.0032
# Val Loss: 0.0032
# Epoch 6/10 [Train]:   0%|          | 0/112 [00:00<?, ?it/s]
# Epoch 6/10 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
# Epoch 6/10
# Train Loss: 0.0031
# Val Loss: 0.0031
# Epoch 7/10 [Train]:   0%|          | 0/112 [00:00<?, ?it/s]
# Epoch 7/10 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
# Epoch 7/10
# Train Loss: 0.0031
# Val Loss: 0.0031
# Epoch 8/10 [Train]:   0%|          | 0/112 [00:00<?, ?it/s]
# Epoch 8/10 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
# Epoch 8/10
# Train Loss: 0.0031
# Val Loss: 0.0030
# Epoch 9/10 [Train]:   0%|          | 0/112 [00:00<?, ?it/s]
# Epoch 9/10 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
# Epoch 9/10
# Train Loss: 0.0031
# Val Loss: 0.0030
# Epoch 10/10 [Train]:   0%|          | 0/112 [00:00<?, ?it/s]
# Epoch 10/10 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
# Epoch 10/10
# Train Loss: 0.0030
# Val Loss: 0.0030

# %%
import torch
import random
import numpy as np
from torch.utils.data import Subset, DataLoader
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from tqdm.notebook import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model = UNet_model(in_channels=23, out_channels=23)
model.load_state_dict(torch.load("/kaggle/working/model_wt.pth", map_location=device))
model.to(device)
model.eval()
print("Model loaded ")

ratio = 0.1
test_sub_size = int(len(test_dataset) * ratio)
test_ind = random.sample(range(len(test_dataset)), test_sub_size)
test_sub_ds = Subset(test_dataset, test_ind)
test_sub_dl = DataLoader(test_sub_ds, batch_size=8, shuffle=False, num_workers=4, pin_memory=True)

predict = []
target = []

with torch.no_grad():
    for inputs, targets in tqdm(test_sub_dl, desc="Evaluating test subset", leave = False):
        inputs = inputs.to(device)
        
        targets = targets.to(device)
        outputs = model(inputs)
        
        predict.append(outputs.cpu().numpy().flatten())
        target.append(targets.cpu().numpy().flatten())

predict = np.concatenate(predict)
target = np.concatenate(target)

r2 = r2_score(target, predict)
mse = mean_squared_error(target, predict)
mae = mean_absolute_error(target, predict)

print("Metrics to evaluate model:")
print(f"R2 Score: {r2:.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Using device: cuda
# Model loaded
# <ipython-input-19-dadc18cefddf>:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/kaggle/working/model_wt.pth", map_location=device))
# Evaluating test subset:   0%|          | 0/25 [00:00<?, ?it/s]
# Metrics to evaluate model:
# R2 Score: 0.8232
# MSE: 0.0028
# MAE: 0.0164

# %% [markdown]
# **Training model on complete dataset**

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from tqdm.notebook import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

model = UNet_model(in_channels=23, out_channels=23).to(device)

loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

num_epoch = 10

for epoch in range(num_epoch):
    model.train()
    train_loss = 0.0
    for inputs, targets in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epoch} [Train]", leave=False):
        inputs = inputs.to(device)
        targets = targets.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
    total_tr_loss = train_loss / len(train_loader)
    
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for inputs, targets in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epoch} [Val]", leave=False):
            inputs = inputs.to(device)
            targets = targets.to(device)
            outputs = model(inputs)
            loss = loss(outputs, targets)
            val_loss += loss.item()
    total_val_loss = val_loss / len(val_loader)
    
    print(f"\nEpoch {epoch+1}/{num_epoch}")
    print(f"Train Loss: {total_tr_loss:.4f}")
    print(f"Val Loss: {total_val_loss:.4f}")
# Out:
# cuda
# Epoch 1/10 [Train]:   0%|          | 0/1126 [00:00<?, ?it/s]
# Epoch 1/10 [Val]:   0%|          | 0/245 [00:00<?, ?it/s]
# Epoch 1/10
# Train Loss: 0.0037
# Val Loss: 0.0027
# Epoch 2/10 [Train]:   0%|          | 0/1126 [00:00<?, ?it/s]
# Epoch 2/10 [Val]:   0%|          | 0/245 [00:00<?, ?it/s]
# Epoch 2/10
# Train Loss: 0.0028
# Val Loss: 0.0026
# Epoch 3/10 [Train]:   0%|          | 0/1126 [00:00<?, ?it/s]
# Epoch 3/10 [Val]:   0%|          | 0/245 [00:00<?, ?it/s]
# Epoch 3/10
# Train Loss: 0.0027
# Val Loss: 0.0026
# Epoch 4/10 [Train]:   0%|          | 0/1126 [00:00<?, ?it/s]
# Epoch 4/10 [Val]:   0%|          | 0/245 [00:00<?, ?it/s]
# Epoch 4/10
# Train Loss: 0.0027
# Val Loss: 0.0025
# Epoch 5/10 [Train]:   0%|          | 0/1126 [00:00<?, ?it/s]
# Epoch 5/10 [Val]:   0%|          | 0/245 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Epoch 8/10 [Val]:   0%|          | 0/245 [00:00<?, ?it/s]
# Epoch 8/10
# Train Loss: 0.0026
# Val Loss: 0.0024
# Epoch 9/10 [Train]:   0%|          | 0/1126 [00:00<?, ?it/s]
# Epoch 9/10 [Val]:   0%|          | 0/245 [00:00<?, ?it/s]
# Epoch 9/10
# Train Loss: 0.0026
# Val Loss: 0.0025
# Epoch 10/10 [Train]:   0%|          | 0/1126 [00:00<?, ?it/s]
# Epoch 10/10 [Val]:   0%|          | 0/245 [00:00<?, ?it/s]
# Epoch 10/10
# Train Loss: 0.0026
# Val Loss: 0.0024

# %%
import torch

torch.save(model.state_dict(), "/projects/academic/courses/cse676s25/swetasah/DL Project/model_weights.pth")

torch.save(model, "/projects/academic/courses/cse676s25/swetasah/DL Project/model_save.pth")

print("Model and weights saved")
# Out:
# Model and weights saved

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.eval()

sum_squared_error = 0.0
sum_absolute_error = 0.0
sum_y = 0.0
sum_y2 = 0.0
n_total = 0


tp = tn = fp = fn = 0

with torch.no_grad():
    for xin, y_true in tqdm(test_loader, desc="Test Eval", leave=False):
        xin, y_true = xin.to(device), y_true.to(device)
        y_pred = model(xin)

        p = y_pred.cpu().numpy().ravel()
        t = y_true.cpu().numpy().ravel()
        batch_n = p.size

        sum_squared_error += ((t - p) ** 2).sum()
        sum_absolute_error += np.abs(t - p).sum()
        sum_y += t.sum()
        sum_y2 += (t ** 2).sum()
        n_total += batch_n

        pbin = p > 0.5
        tbin = t > 0.5
        tp += np.logical_and(pbin, tbin).sum()
        tn += np.logical_and(~pbin, ~tbin).sum()
        fp += np.logical_and(pbin, ~tbin).sum()
        fn += np.logical_and(~pbin, tbin).sum()


mse = sum_squared_error / n_total
mae = sum_absolute_error  / n_total

mean_y = sum_y / n_total
sst = sum_y2 - n_total * (mean_y ** 2)
r2 = 1 - (sum_squared_error / (sst + 1e-8))

print(f"Test MSE: {mse:.6f}")
print(f"Test MAE: {mae:.6f}")
print(f"Test R2: {r2:.6f}")

pixel_acc = (tp + tn) / (tp + tn + fp + fn + 1e-8)
iou = tp / (tp + fp + fn + 1e-8)
prec = tp / (tp + fp + 1e-8)
rec = tp / (tp + fn + 1e-8)
f1 = 2 * prec * rec / (prec + rec + 1e-8)

print(f" Pixel Accuracy: {pixel_acc:.4f}")
print(f" IoU: {iou:.4f}")
print(f" Precision: {prec:.4f}")
print(f" Recall: {rec:.4f}")
print(f" F1 Score: {f1:.4f}")
# Out:
# Test MSE: 0.026659
# Test MAE: 0.108478
# Test R2: -0.879273
#  Pixel Accuracy: 0.9833
#  IoU: 0.0000
#  Precision: 0.0000
#  Recall: 0.0000
#  F1 Score: 0.0000

# %% [markdown]
# **References**
#
# 1. https://tqdm.github.io/
# 2. https://www.geeksforgeeks.org/u-net-architecture-explained/
# 3. https://towardsdatascience.com/understanding-u-net-61276b10f360/
# 4. https://www.analyticsvidhya.com/blog/2022/10/image-segmentation-with-u-net/
# 5. https://medium.com/@alejandro.itoaramendia/decoding-the-u-net-a-complete-guide-810b1c6d56d8
# 6. https://medium.com/@nghihuynh_37300/understanding-evaluation-metrics-in-medical-image-segmentation-d289a373a3f
